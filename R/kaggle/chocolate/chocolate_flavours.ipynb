# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.0.0     ✔ purrr   0.2.5
# ✔ tibble  1.4.2     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# Warning message:
# “package ‘dplyr’ was built under R version 3.5.1”── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
chocolateData <- read_csv("data_sources/flavors_of_cacao.csv")

# some of our column names have spaces in them. This line changes the column names to 
# versions without spaces, which let's us talk about the columns by their names.
names(chocolateData) <- make.names(names(chocolateData), unique=TRUE)
# Out:
# Parsed with column specification:
# cols(
#   `Company
# (Maker-if known)` = col_character(),
#   `Specific Bean Origin
# or Bar Name` = col_character(),
#   REF = col_character(),
#   `Review
# Date` = col_character(),
#   `Cocoa
# Percent` = col_character(),
#   `Company
# Location` = col_character(),
#   Rating = col_character(),
#   `Bean
# Type` = col_character(),
#   `Broad Bean
# Origin` = col_character()
# )

# %%
# the head() function reads just the first few lines of a file. 
head(chocolateData)

# the tail() function reads in the just the last few lines of a file. 
# we can also give both functions a specific number of lines to read.
# This line will read in the last three lines of "chocolateData".
tail(chocolateData, 3)
# Out:
#   Company...Maker.if.known. Specific.Bean.Origin.or.Bar.Name  REF  Review.Date
# 1 (Maker-if known)"         Specific Bean Origin\nor Bar Name REF  Review\nDate
# 2 A. Morin                  Agua Grande                       1876 2016
# 3 A. Morin                  Kpime                             1676 2015
# 4 A. Morin                  Atsane                            1676 2015
# 5 A. Morin                  Akata                             1680 2015
# 6 A. Morin                  Quilla                            1704 2015
#   Cocoa.Percent  Company.Location  Rating Bean.Type  Broad.Bean.Origin
# 1 Cocoa\nPercent Company\nLocation Rating Bean\nType Broad Bean\nOrigin
# 2 63%            France            3.75              Sao Tome
# 3 70%            France            2.75              Togo
# 4 70%            France            3                 Togo
# 5 70%            France            3.5               Togo
# 6 70%            France            3.5               Peru
#   Company...Maker.if.known. Specific.Bean.Origin.or.Bar.Name REF Review.Date
# 1 Zotter                    Kerala State                     749 2011
# 2 Zotter                    Kerala State                     781 2011
# 3 Zotter                    Brazil, Mitzi Blue               486 2010
#   Cocoa.Percent Company.Location Rating Bean.Type Broad.Bean.Origin
# 1 65%           Austria          3.5    Forastero India
# 2 62%           Austria          3.25             India
# 3 65%           Austria          3                Brazil

# %%
# the head() function reads just the first few lines of a file. 
head(chocolateData)

# the tail() function reads in the just the last few lines of a file. 
# we can also give both functions a specific number of lines to read.
# This line will read in the last three lines of "chocolateData".
tail(chocolateData, 3)
# Out:
#   Company...Maker.if.known. Specific.Bean.Origin.or.Bar.Name  REF  Review.Date
# 1 (Maker-if known)"         Specific Bean Origin\nor Bar Name REF  Review\nDate
# 2 A. Morin                  Agua Grande                       1876 2016
# 3 A. Morin                  Kpime                             1676 2015
# 4 A. Morin                  Atsane                            1676 2015
# 5 A. Morin                  Akata                             1680 2015
# 6 A. Morin                  Quilla                            1704 2015
#   Cocoa.Percent  Company.Location  Rating Bean.Type  Broad.Bean.Origin
# 1 Cocoa\nPercent Company\nLocation Rating Bean\nType Broad Bean\nOrigin
# 2 63%            France            3.75              Sao Tome
# 3 70%            France            2.75              Togo
# 4 70%            France            3                 Togo
# 5 70%            France            3.5               Togo
# 6 70%            France            3.5               Peru
#   Company...Maker.if.known. Specific.Bean.Origin.or.Bar.Name REF Review.Date
# 1 Zotter                    Kerala State                     749 2011
# 2 Zotter                    Kerala State                     781 2011
# 3 Zotter                    Brazil, Mitzi Blue               486 2010
#   Cocoa.Percent Company.Location Rating Bean.Type Broad.Bean.Origin
# 1 65%           Austria          3.5    Forastero India
# 2 62%           Austria          3.25             India
# 3 65%           Austria          3                Brazil

# %%
# get the contents in the cell in the sixth row and the forth column
chocolateData[6,4]

# get the contents of every cell in the 6th row (note that you still need the comma!)
chocolateData[6,]

# N.B. if you forget the column comma, you'll get the 6th *column* instead of the 6th *row*
head(chocolateData[6])
# I've used "head" here because the column is very long and I don't want
# to fill up the screen by printing the whole thing out
# Out:
#   Review.Date
# 1 2015
#   Company...Maker.if.known. Specific.Bean.Origin.or.Bar.Name REF  Review.Date
# 1 A. Morin                  Quilla                           1704 2015
#   Cocoa.Percent Company.Location Rating Bean.Type Broad.Bean.Origin
# 1 70%           France           3.5              Peru
#   Company.Location
# 1 Company\nLocation
# 2 France
# 3 France
# 4 France
# 5 France
# 6 France

# %%
# get all rows EXCEPT the first row and all columns of chocolateData
# By putting it back in the same variable, we're overwriting what was in 
# that variable before, so be careful with this!
chocolateData <- chocolateData[-1,] 

# make sure we removed the row we didn't want
head(chocolateData)
# Out:
#   Company...Maker.if.known. Specific.Bean.Origin.or.Bar.Name REF  Review.Date
# 1 A. Morin                  Agua Grande                      1876 2016
# 2 A. Morin                  Kpime                            1676 2015
# 3 A. Morin                  Atsane                           1676 2015
# 4 A. Morin                  Akata                            1680 2015
# 5 A. Morin                  Quilla                           1704 2015
# 6 A. Morin                  Carenero                         1315 2014
#   Cocoa.Percent Company.Location Rating Bean.Type Broad.Bean.Origin
# 1 63%           France           3.75             Sao Tome
# 2 70%           France           2.75             Togo
# 3 70%           France           3                Togo
# 4 70%           France           3.5              Togo
# 5 70%           France           3.5              Peru
# 6 70%           France           2.75   Criollo   Venezuela

# %% [markdown]
# ## Summarising Data

# %%
# Before we get going, let's get rid of the white spaces in the column names of this
# dataset. This will make it possible for us to refer to columns by thier names, since
# any white space in a name will mess R up.
chocolateData <- read_csv("data_sources/flavors_of_cacao.csv")
# Remove duplicate header row
chocolateData <- chocolateData[-1,] 
names(chocolateData) <- gsub("[[:space:]+]", "_", names(chocolateData))
str(chocolateData)
# Out:
# Parsed with column specification:
# cols(
#   `Company
# (Maker-if known)` = col_character(),
#   `Specific Bean Origin
# or Bar Name` = col_character(),
#   REF = col_character(),
#   `Review
# Date` = col_character(),
#   `Cocoa
# Percent` = col_character(),
#   `Company
# Location` = col_character(),
#   Rating = col_character(),
#   `Bean
# Type` = col_character(),
#   `Broad Bean
# Origin` = col_character()
# )
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	1795 obs. of  9 variables:
#  $ Company__(Maker-if_known)       : chr  "A. Morin" "A. Morin" "A. Morin" "A. Morin" ...
#  $ Specific_Bean_Origin_or_Bar_Name: chr  "Agua Grande" "Kpime" "Atsane" "Akata" ...
#  $ REF                             : chr  "1876" "1676" "1676" "1680" ...
#  $ Review_Date                     : chr  "2016" "2015" "2015" "2015" ...
#  $ Cocoa_Percent                   : chr  "63%" "70%" "70%" "70%" ...
#  $ Company_Location                : chr  "France" "France" "France" "France" ...
#  $ Rating                          : chr  "3.75" "2.75" "3" "3.5" ...
#  $ Bean_Type                       : chr  " " " " " " " " ...
#  $ Broad_Bean_Origin               : chr  "Sao Tome" "Togo" "Togo" "Togo" ...

# %%
#print the first few values from the column named "Rating" in the dataframe "chocolateData" 
head(chocolateData$Rating)
# Out:
# [1] "3.75" "2.75" "3"    "3.5"  "3.5"  "2.75"

# %%
# automatically convert the data types of our data_frame
# The tidyverse has a lot of nice utility functions that can make our lives much easier. 
# One of them is type_convert, which will look at the first 1000 rows of each column, 
# guess what the data type of that column should be and then convert that column into that data type.
chocolateData <- type_convert(chocolateData)
# Out:
# Parsed with column specification:
# cols(
#   `Company__(Maker-if_known)` = col_character(),
#   Specific_Bean_Origin_or_Bar_Name = col_character(),
#   REF = col_integer(),
#   Review_Date = col_integer(),
#   Cocoa_Percent = col_character(),
#   Company_Location = col_character(),
#   Rating = col_double(),
#   Bean_Type = col_character(),
#   Broad_Bean_Origin = col_character()
# )

# %%
str(chocolateData)
# Out:
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	1795 obs. of  9 variables:
#  $ Company__(Maker-if_known)       : chr  "A. Morin" "A. Morin" "A. Morin" "A. Morin" ...
#  $ Specific_Bean_Origin_or_Bar_Name: chr  "Agua Grande" "Kpime" "Atsane" "Akata" ...
#  $ REF                             : int  1876 1676 1676 1680 1704 1315 1315 1315 1319 1319 ...
#  $ Review_Date                     : int  2016 2015 2015 2015 2015 2014 2014 2014 2014 2014 ...
#  $ Cocoa_Percent                   : chr  "63%" "70%" "70%" "70%" ...
#  $ Company_Location                : chr  "France" "France" "France" "France" ...
#  $ Rating                          : num  3.75 2.75 3 3.5 3.5 2.75 3.5 3.5 3.75 4 ...
#  $ Bean_Type                       : chr  " " " " " " " " ...
#  $ Broad_Bean_Origin               : chr  "Sao Tome" "Togo" "Togo" "Togo" ...

# %%
# remove all the percent signs in the fifth column. You don't really need to worry about
# all the different things that are happening in this line right now. 
chocolateData$Cocoa_Percent <- sapply(chocolateData$Cocoa_Percent, function(x) gsub("%", "", x))

# try the type_convert() function agian
chocolateData <- type_convert(chocolateData)

# check the structure to make sure it actually is a percent
str(chocolateData)
# Out:
# Parsed with column specification:
# cols(
#   `Company__(Maker-if_known)` = col_character(),
#   Specific_Bean_Origin_or_Bar_Name = col_character(),
#   Cocoa_Percent = col_double(),
#   Company_Location = col_character(),
#   Bean_Type = col_character(),
#   Broad_Bean_Origin = col_character()
# )
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	1795 obs. of  9 variables:
#  $ Company__(Maker-if_known)       : chr  "A. Morin" "A. Morin" "A. Morin" "A. Morin" ...
#  $ Specific_Bean_Origin_or_Bar_Name: chr  "Agua Grande" "Kpime" "Atsane" "Akata" ...
#  $ REF                             : int  1876 1676 1676 1680 1704 1315 1315 1315 1319 1319 ...
#  $ Review_Date                     : int  2016 2015 2015 2015 2015 2014 2014 2014 2014 2014 ...
#  $ Cocoa_Percent                   : num  63 70 70 70 70 70 70 70 70 70 ...
#  $ Company_Location                : chr  "France" "France" "France" "France" ...
#  $ Rating                          : num  3.75 2.75 3 3.5 3.5 2.75 3.5 3.5 3.75 4 ...
#  $ Bean_Type                       : chr  " " " " " " " " ...
#  $ Broad_Bean_Origin               : chr  "Sao Tome" "Togo" "Togo" "Togo" ...

# %%
# run this cell to learn more about the summary() function
?summary

# %%
# run this cell to learn more about the summarise_all() function
?summarise_all

# %%
# summary function from base R (base R means no packages)
summary(chocolateData)
# Out:
#  Company__(Maker-if_known) Specific_Bean_Origin_or_Bar_Name      REF
#  Length:1795               Length:1795                      Min.   :   5
#  Class :character          Class :character                 1st Qu.: 576
#  Mode  :character          Mode  :character                 Median :1069
#                                                             Mean   :1036
#                                                             3rd Qu.:1502
#                                                             Max.   :1952
#   Review_Date   Cocoa_Percent   Company_Location       Rating
#  Min.   :2006   Min.   : 42.0   Length:1795        Min.   :1.000
#  1st Qu.:2010   1st Qu.: 70.0   Class :character   1st Qu.:2.875
#  Median :2013   Median : 70.0   Mode  :character   Median :3.250
#  Mean   :2012   Mean   : 71.7                      Mean   :3.186
#  3rd Qu.:2015   3rd Qu.: 75.0                      3rd Qu.:3.500
#  Max.   :2017   Max.   :100.0                      Max.   :5.000
#   Bean_Type         Broad_Bean_Origin
#  Length:1795        Length:1795
#  Class :character   Class :character
#  Mode  :character   Mode  :character

# %%
# summary function from the Tidyverse (specifically dplyr). To use this function, you need
# to tell it what dataset to summarize and also what function to use. In this case I'm
# asking for the average using the function mean()
summarise_all(chocolateData, funs(mean))
summarise_all(chocolateData, funs(sd))
# Out:
# Warning message in mean.default(`Company__(Maker-if_known)`):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(Specific_Bean_Origin_or_Bar_Name):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(Company_Location):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(Bean_Type):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(Broad_Bean_Origin):
# “argument is not numeric or logical: returning NA”
#   Company__(Maker-if_known) Specific_Bean_Origin_or_Bar_Name REF
# 1 NA                        NA                               1035.905
#   Review_Date Cocoa_Percent Company_Location Rating   Bean_Type
# 1 2012.325    71.69833      NA               3.185933 NA
#   Broad_Bean_Origin
# 1 NA
# Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”
#   Company__(Maker-if_known) Specific_Bean_Origin_or_Bar_Name REF
# 1 NA                        NA                               552.8864
#   Review_Date Cocoa_Percent Company_Location Rating    Bean_Type
# 1 2.92721     6.323118      NA               0.4780624 NA
#   Broad_Bean_Origin
# 1 NA

# %%
# return a data_frame with the mean and sd of the Rating column, from the chocolate
# dataset in it
chocolateData %>%
    summarise(averageRating = mean(Rating),
             sdRating = sd(Rating))
# Out:
#   averageRating sdRating
# 1 3.185933      0.4780624

# %% [markdown]
# ## Graphing

# %%
# draw a blank plot with "Review_Date" as the x axis and "Rating" as the y axis.
ggplot(chocolateData, aes(x= Review_Date, y = Rating))
# Out:
# plot without title

# %%
# draw a plot with "Review_Date" as the x axis and "Rating" as the y axis, and add a point for each data point
ggplot(chocolateData, aes(x= Review_Date, y = Rating)) + geom_point()
# Out:
# plot without title

# %%
# draw a plot with "Review_Date" as the x axis and "Rating" as the y axis, add a point for each data point & move each point slightly so they don't overlap
ggplot(chocolateData, aes(x= Review_Date, y = Rating)) + geom_point() + geom_jitter()
# Out:
# plot without title

# %%
# draw a plot with "Review_Date" as the x axis and "Rating" as the y axis, add a point for each data point, move each point slightly so they don't overlap and add a smoothed line (lm = linear model)
ggplot(chocolateData, aes(x= Review_Date, y = Rating)) + 
    geom_point() + 
    geom_jitter() +
    geom_smooth(method = 'lm')
# Out:
# plot without title

# %%
# Plotting Ratings against Cocoa Percentage
ggplot(chocolateData, aes(x= Cocoa_Percent, y = Rating)) + 
    geom_point() + 
    geom_jitter() 
#     geom_smooth(method = 'lm')
# Out:
# plot without title

# %%
# save our plot to a variable with an informative name
chocolateRatingByReviewDate <- ggplot(chocolateData, aes(x= Review_Date, y = Rating, color = Cocoa_Percent)) + 
    geom_point() + 
    geom_jitter() +
    geom_smooth(method = 'lm')

# save our plot
ggsave("chocolateRatingByReviewDate.png", # the name of the file where it will be save
       plot = chocolateRatingByReviewDate, # what plot to save
       height=6, width=10, units="in") # the size of the plot & units of the size

# notice that this cell doesn't have any output in place! That's because in the first section we're 
# giving the plot a name rather than printing it, and in the second we're saving our plot rather 
# than printing it. We've never actually said to print our plot at any point.

# %%
# Return the average and sd of ratings by the year a rating was given
averageRatingByYear <- chocolateData %>%
    group_by(Review_Date) %>%
    summarise(averageRating = mean(Rating))

# plot only the average rating by year
ggplot(averageRatingByYear, aes(y= averageRating, x = Review_Date )) + 
    geom_point() + # plot individual points
    geom_line() # plot line
# Out:
# plot without title
