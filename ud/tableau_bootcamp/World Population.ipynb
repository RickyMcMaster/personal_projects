# %%
import pandas as pd

url2 = 'https://unstats.un.org/unsd/methodology/m49/'
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)'
df_list = pd.read_html(url)

# %%
df = df_list[3]
df.rename(columns = {'Country/Territory':'Country'}, inplace = True)
df.head(20)
# Out:
#           Country UN continentalregion[4] UN statisticalsubregion[4]  \
# 0        China[a]                    Asia               Eastern Asia
# 1           India                    Asia              Southern Asia
# 2   United States                Americas           Northern America
# 3       Indonesia                    Asia         South-eastern Asia
# 4        Pakistan                    Asia              Southern Asia
# 5          Brazil                Americas              South America
# 6         Nigeria                  Africa             Western Africa
# 7      Bangladesh                    Asia              Southern Asia
# 8          Russia                  Europe             Eastern Europe
# 9          Mexico                Americas            Central America
# 10          Japan                    Asia               Eastern Asia
# 11       Ethiopia                  Africa             Eastern Africa
# 12    Philippines                    Asia         South-eastern Asia
# ...

# %%
new = df["Country"].str.split("[", n = 1, expand = True) 
df['Country2'] = new[0]
df.drop(columns='Country', inplace=True)

# %%
df.rename(columns = {'Country2':'Country', 'UN continentalregion[4]':'Continent', 'UN statisticalsubregion[4]': 'Region'}, inplace = True)
df.head()
# Out:
#   Continent              Region  Population(1 July 2018)  \
# 0      Asia        Eastern Asia               1427647786
# 1      Asia       Southern Asia               1352642280
# 2  Americas    Northern America                327096265
# 3      Asia  South-eastern Asia                267670543
# 4      Asia       Southern Asia                212228286
#
#    Population(1 July 2019)  Change        Country
# 0               1433783686  +0.43%          China
# 1               1366417754  +1.02%          India
# 2                329064917  +0.60%  United States
# 3                270625568  +1.10%      Indonesia
# 4                216565318  +2.04%       Pakistan

# %%
df3.head()
# Out:
#           Country Alpha-2 code Alpha-3 code  Numeric code  \
# 0     Afghanistan           AF          AFG             4
# 1   Åland Islands           AX          ALA           248
# 2         Albania           AL          ALB             8
# 3         Algeria           DZ          DZA            12
# 4  American Samoa           AS          ASM            16
#
#   Link to ISO 3166-2 subdivision codes Independent
# 0                        ISO 3166-2:AF         Yes
# 1                        ISO 3166-2:AX          No
# 2                        ISO 3166-2:AL         Yes
# 3                        ISO 3166-2:DZ         Yes
# 4                        ISO 3166-2:AS          No

# %%
df4 = pd.read_csv('countries.tsv', sep='\t')
df4.rename(columns = {'country':'Country'}, inplace=True)
df4.head()
# Out:
#   cca2         Country                             officialName tld  \
# 0   AF     Afghanistan          Islamic Republic of Afghanistan  af
# 1   AX   Åland Islands                            Åland Islands  ax
# 2   AL         Albania                      Republic of Albania  al
# 3   DZ         Algeria  People's Democratic Republic of Algeria  dz
# 4   AS  American Samoa                           American Samoa  as
#
#            tlds cca3 currencies    capital    languages   region  \
# 0           .af  AFG        AFN      Kabul  prs,pus,tuk     Asia
# 1           .ax  ALA        EUR  Mariehamn          swe   Europe
# 2           .al  ALB        ALL     Tirana          sqi   Europe
# 3  .dz,الجزائر.  DZA        DZD    Algiers          ara   Africa
# 4           .as  ASM        USD  Pago Pago      eng,smo  Oceania
#
#          subregion  eu
# 0    Southern Asia NaN
# 1  Northern Europe NaN
# 2  Southern Europe NaN
# 3  Northern Africa NaN
# 4        Polynesia NaN

# %%
df_list2 = pd.read_html(url2)
df2 = df_list2[0]

# %%
url3 = 'https://en.wikipedia.org/wiki/ISO_3166-1'
df_list3 = pd.read_html(url3)
df3 = df_list3[1]
df3.rename(columns = {'English short name (using title case)':'Country'}, inplace = True)

df3['Country'] = df3['Country'].replace(['Russian Federation','United Republic of Tanzania'],['Russia','Tanzania'])

# %%
# df3.loc[df3['Change'].isnull(),'Country'].head(30)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Change'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-fafe078b00ce> in <module>
# ...

# %%
df3['Country'] = df3['Country'].replace(['Russian Federation','United States of America'],['Russia','United States'])
df_fin = pd.merge(df, df3, on='Country', how='left')
df_fin.loc[df_fin['Independent'].isnull(),['Country']].head(20)

# %%
df_fin = pd.merge(df, df4, on='Country', how='left')
df_fin.head(20)
# Out:
#    Continent              Region  Population(1 July 2018)  \
# 0       Asia        Eastern Asia               1427647786
# 1       Asia       Southern Asia               1352642280
# 2   Americas    Northern America                327096265
# 3       Asia  South-eastern Asia                267670543
# 4       Asia       Southern Asia                212228286
# 5   Americas       South America                209469323
# 6     Africa      Western Africa                195874683
# 7       Asia       Southern Asia                161376708
# 8     Europe      Eastern Europe                145734038
# 9   Americas     Central America                126190788
# 10      Asia        Eastern Asia                127202192
# 11    Africa      Eastern Africa                109224414
# 12      Asia  South-eastern Asia                106651394
# 13    Africa     Northern Africa                 98423598
# 14      Asia  South-eastern Asia                 95545962
# ...

# %%
df_fin.to_excel('world_pop.xlsx')

# %%
df2.to_csv('country_codes.csv')

# %%
import pycountry

# %%
germany = pycountry.countries.get(alpha_2='DE')
germany
# Out:
# Country(alpha_2='DE', alpha_3='DEU', name='Germany', numeric='276', official_name='Federal Republic of Germany')

# %%
russia = pycountry.countries.get(alpha_2='RU')
russia
# Out:
# Country(alpha_2='RU', alpha_3='RUS', name='Russian Federation', numeric='643')

# %%
# check out fuzzy matching on country name:
# https://pypi.org/project/pycountry/
